# %%
import numpy as np

# %%
arr = np.array([10, 20, 30, 40])
print(arr[0])  # 10
print(arr[-1]) # 40
# Out:
# 10
# 40

# %%
# Slicing (Extracting Parts of an Array)

arr = np.array([10, 20, 30, 40, 50])

print(arr[1:4])  # [20 30 40] (slice from index 1 to 3)
print(arr[:3])   # [10 20 30] (first 3 elements)
print(arr[::2])  # [10 30 50] (every 2nd element)
# Out:
# [20 30 40]
# [10 20 30]
# [10 30 50]

# %%
sliced = arr[1:4]
sliced[0] = 999
print(arr)  # [10 999 30 40 50]
# Out:
# [ 10 999  30  40  50]

# %%
# fancy indexing

arr = np.array([10, 20, 30, 40, 50])
idx = [0, 2, 4]  # Indices to select
print(arr[idx])  # [10 30 50]
# Out:
# [10 30 50]

# %%
# boolean indexing

arr = np.array([10, 20, 30, 40, 50])
mask = arr > 25  # Condition: values greater than 25
print(arr[mask])  # [30 40 50]
# Out:
# [30 40 50]

# %% [markdown]
# Exercises for Practice
# Create a 3×3 array filled with random numbers and print its shape.
# Convert an array of floats [1.1, 2.2, 3.3] into integers.
# Use fancy indexing to extract even numbers from [1, 2, 3, 4, 5, 6].
# Reshape a 1D array of size 9 into a 3×3 matrix.
# Use boolean masking to filter numbers greater than 50 in an array.

# %%
arr1 = np.array([[[2,4,6,],[5,3,6],[33,6,8]]])

print("Shape:", arr.shape)
# Out:
# Shape: (1, 3, 3)

# %%
arr1 = np.array([[[2,4,6,],[5,3,6],[33,6,8]]], dtype=np.float32)

arr1
# Out:
# array([[[ 2.,  4.,  6.],
#         [ 5.,  3.,  6.],
#         [33.,  6.,  8.]]], dtype=float32)

# %%
arr1 = arr1.astype(np.int32)
arr1
# Out:
# array([[[ 2,  4,  6],
#         [ 5,  3,  6],
#         [33,  6,  8]]], dtype=int32)

# %%
even = arr1 % 2 == 0

print(arr[even])
# Out:
# [2 4 6 6 6 8]

# %%
reshaped = arr1.reshape(9)

print("Reshape:", reshaped)
print("shape:", arr1.shape)
# Out:
# Reshape: [ 2  4  6  5  3  6 33  6  8]
# shape: (1, 3, 3)

# %%
mask = arr1>5
print(arr1[mask])
# Out:
# [ 6  6 33  6  8]
