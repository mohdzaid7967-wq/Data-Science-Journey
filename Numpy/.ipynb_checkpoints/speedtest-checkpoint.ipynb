# %%
import numpy as np
import time 

# uusing python list 
size = 1_000_00

l1 = list(range(size))
l2 = list(range(size))

start = time.time()
add = [x+y for x,y in zip(l1,l2)]
end = time.time()

print(end-start)
# Out:
# 0.011997461318969727

# %%
import numpy as np
import time 

# using numpy array 

size = 1_000_00

l1 = np.array(list(range(size)))
l2 = np.array(list(range(size)))

start = time.time()
add = l1 + l2
end = time.time()

print(end-start)
# Out:
# 0.007001638412475586

# %%
# memory consumption list vs numpy
import sys

list_data = list(range(1_000))
numpy_data = np.array(list_data)

print("Python list size:", sys.getsizeof(list_data) * len(list_data), "bytes")
print("Numpy array size:", numpy_data.nbytes, "bytes")
# Out:
# Python list size: 8056000 bytes
# Numpy array size: 8000 bytes

# %%
# vectorization

list1 = [2,4,3,6,4,2]
# python list 
list_square = [x ** 2 for x in list1]
print(list_square)

arr = np.array([2,4,3,63,2,])
# numpy
numpy_squares = arr ** 2
print(numpy_squares)
# Out:
# [4, 16, 9, 36, 16, 4]
# [   4   16    9 3969    4]
