# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age, df.bought_insurance, color='red',marker='+')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(df[['age']],df.bought_insurance, test_size=0.1)

# %%
len(X_train)
# Out:
# 24

# %%
X_train
# Out:
#     age
# 19   18
# 4    46
# 11   28
# 5    56
# 10   18
# 7    60
# 21   26
# 1    25
# 8    62
# 25   54
# 22   40
# 15   55
# 9    61
# 3    52
# 16   25
# 18   19
# 12   27
# 24   50
# 20   21
# 26   23
# 17   58
# 23   45
# 2    47
# 13   29

# %%
X_test
# Out:
#     age
# 0    22
# 14   49
# 6    55

# %%
len(X_test)
# Out:
# 3

# %%
y_train
# Out:
# 19    0
# 4     1
# 11    0
# 5     1
# 10    0
# 7     1
# 21    0
# 1     0
# 8     1
# 25    1
# 22    1
# 15    1
# 9     1
# 3     0
# 16    1
# 18    0
# 12    0
# 24    1
# 20    0
# 26    0
# 17    1
# 23    1
# 2     1
# 13    0
# Name: bought_insurance, dtype: int64

# %%
len(y_train)
# Out:
# 24

# %%
y_test
# Out:
# 0     0
# 14    1
# 6     0
# Name: bought_insurance, dtype: int64

# %%
len(y_test)
# Out:
# 3

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 0    22
# 14   49
# 6    55

# %%
model.predict(X_test)
# Out:
# array([0, 1, 1])

# %%
model.predict([[25]])
# Out:
# C:\Users\Mohd Zaid\anaconda3\envs\data-science\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
X_test
# Out:
#     age
# 0    22
# 14   49
# 6    55

# %%
model.predict_proba(X_test)
# Out:
# array([[0.91937095, 0.08062905],
#        [0.11370506, 0.88629494],
#        [0.04519099, 0.95480901]])

# %%
model.score(X_test,y_test)
# Out:
# 0.6666666666666666
