# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("homeprices.csv")
df.head()
# Out:
#               town  area   price
# 0  monroe township  2600  550000
# 1  monroe township  3000  565000
# 2  monroe township  3200  610000
# 3  monroe township  3600  680000
# 4  monroe township  4000  725000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   town    13 non-null     str
#  1   area    13 non-null     int64
#  2   price   13 non-null     int64
# dtypes: int64(2), str(1)
# memory usage: 444.0 bytes

# %%
dummies = pd.get_dummies(df.town)
dummies
# Out:
#     monroe township  robinsville  west windsor
# 0              True        False         False
# 1              True        False         False
# 2              True        False         False
# 3              True        False         False
# 4              True        False         False
# 5             False        False          True
# 6             False        False          True
# 7             False        False          True
# 8             False        False          True
# 9             False         True         False
# 10            False         True         False
# 11            False         True         False
# 12            False         True         False

# %%
df_dummies = pd.concat([df,dummies],axis='columns')
df_dummies
# Out:
#                town  area   price  monroe township  robinsville  west windsor
# 0   monroe township  2600  550000             True        False         False
# 1   monroe township  3000  565000             True        False         False
# 2   monroe township  3200  610000             True        False         False
# 3   monroe township  3600  680000             True        False         False
# 4   monroe township  4000  725000             True        False         False
# 5      west windsor  2600  585000            False        False          True
# 6      west windsor  2800  615000            False        False          True
# 7      west windsor  3300  650000            False        False          True
# 8      west windsor  3600  710000            False        False          True
# 9       robinsville  2600  575000            False         True         False
# 10      robinsville  2900  600000            False         True         False
# 11      robinsville  3100  620000            False         True         False
# 12      robinsville  3600  695000            False         True         False

# %%
df_dummies.drop(['town','west windsor'],axis='columns',inplace=True)
df_dummies
# Out:
#     area   price  monroe township  robinsville
# 0   2600  550000             True        False
# 1   3000  565000             True        False
# 2   3200  610000             True        False
# 3   3600  680000             True        False
# 4   4000  725000             True        False
# 5   2600  585000            False        False
# 6   2800  615000            False        False
# 7   3300  650000            False        False
# 8   3600  710000            False        False
# 9   2600  575000            False         True
# 10  2900  600000            False         True
# 11  3100  620000            False         True
# 12  3600  695000            False         True

# %%
X = df_dummies.drop(['price'],axis='columns')
X
# Out:
#     area  monroe township  robinsville
# 0   2600             True        False
# 1   3000             True        False
# 2   3200             True        False
# 3   3600             True        False
# 4   4000             True        False
# 5   2600            False        False
# 6   2800            False        False
# 7   3300            False        False
# 8   3600            False        False
# 9   2600            False         True
# 10  2900            False         True
# 11  3100            False         True
# 12  3600            False         True

# %%
y = df_dummies.price
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[3000,0,0]])
# Out:
# C:\Users\Mohd Zaid\anaconda3\envs\data-science\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([630482.69189422])

# %%
model.predict([[2800,0,1]])
# Out:
# C:\Users\Mohd Zaid\anaconda3\envs\data-science\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([590775.63964739])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dfle = df

# %%
dfle
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
dfle.town = le.fit_transform(dfle.town)

# %%
X = dfle[['town','area']].values
X
# Out:
# array([[   0, 2600],
#        [   0, 3000],
#        [   0, 3200],
#        [   0, 3600],
#        [   0, 4000],
#        [   2, 2600],
#        [   2, 2800],
#        [   2, 3300],
#        [   2, 3600],
#        [   1, 2600],
#        [   1, 2900],
#        [   1, 3100],
#        [   1, 3600]])

# %%
y = dfle.price

# %%
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

ct = ColumnTransformer(
    transformers=[
        ("town", OneHotEncoder(), ["town"])
    ],
    remainder="passthrough"
)

# %%
X = ct.fit_transform(dfle)

# %%
X
# Out:
# array([[1.00e+00, 0.00e+00, 0.00e+00, 2.60e+03, 5.50e+05],
#        [1.00e+00, 0.00e+00, 0.00e+00, 3.00e+03, 5.65e+05],
#        [1.00e+00, 0.00e+00, 0.00e+00, 3.20e+03, 6.10e+05],
#        [1.00e+00, 0.00e+00, 0.00e+00, 3.60e+03, 6.80e+05],
#        [1.00e+00, 0.00e+00, 0.00e+00, 4.00e+03, 7.25e+05],
#        [0.00e+00, 0.00e+00, 1.00e+00, 2.60e+03, 5.85e+05],
#        [0.00e+00, 0.00e+00, 1.00e+00, 2.80e+03, 6.15e+05],
#        [0.00e+00, 0.00e+00, 1.00e+00, 3.30e+03, 6.50e+05],
#        [0.00e+00, 0.00e+00, 1.00e+00, 3.60e+03, 7.10e+05],
#        [0.00e+00, 1.00e+00, 0.00e+00, 2.60e+03, 5.75e+05],
#        [0.00e+00, 1.00e+00, 0.00e+00, 2.90e+03, 6.00e+05],
#        [0.00e+00, 1.00e+00, 0.00e+00, 3.10e+03, 6.20e+05],
#        [0.00e+00, 1.00e+00, 0.00e+00, 3.60e+03, 6.95e+05]])

# %%
X = X[:,1:]
X
# Out:
# array([[0.00e+00, 0.00e+00, 2.60e+03, 5.50e+05],
#        [0.00e+00, 0.00e+00, 3.00e+03, 5.65e+05],
#        [0.00e+00, 0.00e+00, 3.20e+03, 6.10e+05],
#        [0.00e+00, 0.00e+00, 3.60e+03, 6.80e+05],
#        [0.00e+00, 0.00e+00, 4.00e+03, 7.25e+05],
#        [0.00e+00, 1.00e+00, 2.60e+03, 5.85e+05],
#        [0.00e+00, 1.00e+00, 2.80e+03, 6.15e+05],
#        [0.00e+00, 1.00e+00, 3.30e+03, 6.50e+05],
#        [0.00e+00, 1.00e+00, 3.60e+03, 7.10e+05],
#        [1.00e+00, 0.00e+00, 2.60e+03, 5.75e+05],
#        [1.00e+00, 0.00e+00, 2.90e+03, 6.00e+05],
#        [1.00e+00, 0.00e+00, 3.10e+03, 6.20e+05],
#        [1.00e+00, 0.00e+00, 3.60e+03, 6.95e+05]])

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[1,0,2800]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 model.predict([[1,0,2800]])
#
# File ~\anaconda3\envs\data-science\Lib\site-packages\sklearn\linear_model\_base.py:355, in MultiOutputLinearModel.predict(self, X)
#     341 def predict(self, X):
#     342     """
#     343     Predict using the linear model.
#     344
#    (...)    353         Predicted values.
#     354     """
# --> 355     return super().predict(X)
#
# File ~\anaconda3\envs\data-science\Lib\site-packages\sklearn\linear_model\_base.py:316, in LinearModel.predict(self, X)
#     302 """
#     303 Predict using the linear model.
#     304
#    (...)    313     Predicted values.
#     314 """
#     315 check_same_namespace(X, self, attribute="coef_", method="predict")
# --> 316 return self._decision_function(X)
#
# File ~\anaconda3\envs\data-science\Lib\site-packages\sklearn\linear_model\_base.py:294, in LinearModel._decision_function(self, X)
#     291 def _decision_function(self, X):
#     292     check_is_fitted(self)
# --> 294     X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     295     coef_ = self.coef_
#     296     if coef_.ndim == 1:
#
# File ~\anaconda3\envs\data-science\Lib\site-packages\sklearn\utils\validation.py:3059, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3056     out = X, y
#    3058 if not no_val_X and check_params.get("ensure_2d", True):
# -> 3059     _check_n_features(_estimator, X, reset=reset)
#    3061 return out
#
# File ~\anaconda3\envs\data-science\Lib\site-packages\sklearn\utils\validation.py:2923, in _check_n_features(estimator, X, reset)
#    2920     return
#    2922 if n_features != estimator.n_features_in_:
# -> 2923     raise ValueError(
#    2924         f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2925         f"is expecting {estimator.n_features_in_} features as input."
#    2926     )
#
# ValueError: X has 3 features, but LinearRegression is expecting 4 features as input.
